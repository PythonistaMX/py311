# %% [markdown]
# [![img/pythonista.png](img/pythonista.png)](https://www.pythonista.io)

# %% [markdown]
# # Elementos de un gráfico de *Matplotlib*.

# %% [markdown]
# *Matplotlib* es la biblioteca de visualización de datos más utilizada en el ecosistema de *Python* y es la base a partir de la cual se construyen muchas otras bibliotecas de visualización.
#
# *Matplotlib* permite crear gráficos de alta calidad con una gran variedad de opciones de personalización. En esta sección se describen los elementos básicos que componen un gráfico de *Matplotlib* y cómo personalizarlos.
#
#
# https://matplotlibguide.readthedocs.io/en/latest/Matplotlib/basic.html

# %%
import matplotlib as mpl
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Preliminares.

# %% [markdown]
# ### Ajuste de la *notebook* para ejecución del modo interactivo.
#
# La interfaz de *IPython* permite desplegar figuras e imágenes generadas por *Matplotlib* mediante el siguiete comando mágico.
#
# ```
# %matplotlib inline
# ```
#
# https://ipython.readthedocs.io/en/stable/interactive/magics.html#magic-matplotlib

# %%
# %matplotlib inline

# %% [markdown]
# ### Datos ilustrativos.

# %% [markdown]
# * La siguienten celda definirá al arregl;o ```x``` el cual contiene un espacio lineal con ```50```segmentos que van de ```-50``` a ```50```.

# %%
x = np.linspace(-50, 50, 50)
x

# %% [markdown]
# * La siguiente celda definirá al arreglo ```y```, el cual contienen el resultado de la operación ```(x ** 2) - (2 * x)```.

# %%
y = (x ** 2) - (2 * x)
y

# %% [markdown]
# * La siguiente celda definirá al arreglo ```z```, el cual contienen el resultado de la operación ```x ** 2 * (1 + np.sin(x))```.

# %%
z = x ** 2 * (1 +  np.sin(x))
z

# %% [markdown]
# * La siguiente celda trazará una gráfica usando al arreglo ```x``` como el conjunto de datos paras el eje $x$ y ```y``` y ```z``` como funciones de $x$ que serán representadas en el eje $y$ utilizando el método ```plt.plot()```. Se utilizarán los parámetros por defecto.

# %%
plt.plot(x, y, x, z)

# %% [markdown]
# ## Los objetos *figure*.

# %% [markdown]
# Los elementos base para el trazado de gráficos con *Matplotlib* son los objetos *figure*, los cuales son instancias de la clase ```matplotlib.figure.Figure```.
#
# Todos los elementos de un gráfico de *Matplotlib* son parte de un objeto *figure*, el cual es el contenedor principal para todos los elementos gráficos. Un objeto *figure* puede contener uno o más objetos *axes*, los cuales son los que realmente contienen los gráficos y las visualizaciones.
#
# https://matplotlib.org/stable/api/figure_api.html#matplotlib.figure.Figure

# %% [markdown]
# ### La función ```plt.figure()```.
#
# Para poder crear un objeto *figure* se utiliza el método ```plt.figure```.
#
# Los objetos *figure* no son creados de forma automática, por lo que es necesario crear un objeto *figure* antes de poder crear cualquier otro elemento gráfico. Sin embargo, si se intenta crear un elemento gráfico sin haber creado un objeto *figure* previamente, *Matplotlib* creará automáticamente un objeto *figure* con los parámetros por defecto. Para evitar esto, es recomendable crear un objeto *figure* de forma explícita antes de crear cualquier otro elemento gráfico.
#
# Los objetos *figure* no se despliegan por sí mismos, sino que son contenedores para otros elementos gráficos. Para desplegar un objeto *figure* es necesario crear un objeto *axes* dentro del objeto *figure* y luego trazar los gráficos dentro del objeto *axes*.
#
# ```
# plt.figure(num=<id>, label=<etiqueta>, figsize=<tamaño>, dpi=<resolución>)
# ```
#
# Donde:
#
# * ```<id>``` es un identificador único del objeto *figure*. En caso de no definirse, el identificador será un número que iniciará en ```1``` e irá incrementándose de 1 en 1.
# * ```<etiqueta>``` es una cadena de texto que sirve como etiqueta para la figura.
# * ```<tamaño>``` es una tupla de dos elementos cuyo primer elemento define el ancho y el segundo la altura de la figura.
# * ```<resolución>``` que corresponde al número de *dpi* (puntos por pulgada) de la figura.
#
# Por convención se le asigna el nombre ```fig``` al objeto *figure*.
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html

# %% [markdown]
# ### Objetos *figure* en celdas de *IPython/Jupyter*.
#
# Los objetos *figure* de *Matplotlib* en celdas de *IPython/Jupyter* sólo existen mientras la celda que las creó esté activa. Si se ejecuta otra celda, la figura creada en la celda anterior se cerrará automáticamente. Para evitar esto, es necesario crear un objeto *figure* de forma explícita y luego trazar los gráficos dentro del objeto *axes* asociado a ese objeto *figure*. De esta manera, la figura permanecerá activa incluso después de ejecutar otras celdas.

# %% [markdown]
# **Ejemplo**:

# %% [markdown]
# * La siguienten celda creará un objeto *figure* con un tamaño de 15x7 pulgadas y una resolución de 50 dpi. El objeto *figure* se almacenará en la variable ```fig```.

# %%
fig = plt.figure(dpi=50, figsize=(15, 7))

# %% [markdown]
# ### Gestión de los objetos *figure*.
#
# Aún cuando pueden existir varios objetos *figure* al mismo tiempo, sólo uno de ellos puede estar activo en un momento dado. El objeto *figure* activo es el que se utilizará para trazar los gráficos y las visualizaciones. Para cambiar el objeto *figure* activo, se puede utilizar el método ```plt.figure()``` con el identificador del objeto *figure* que se desea activar.
#
# ```
# plt.figure(<id>)
# ```
# Donde ```<id>``` es el identificador del objeto *figure* que se desea activar. Si el objeto *figure*   con el identificador especificado no existe, se creará un nuevo objeto *figure* con ese identificador.
#
# Existen múltiples métodos para gestionar los objetos *figure* en *Matplotlib*, como por ejemplo:
#
# * [`plt.gcf()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.gcf.html) que devuelve el objeto *figure* activo.
# * [`plt.get_fignums()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.get_fignums.html) que devuelve una lista con los identificadores de todos los objetos *figure* existentes.
# * [`plt.get_figlabels()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.get_figlabels.html) que devuelve una lista con las etiquetas de todos los objetos *figure* existentes.
# * [`plt.close()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.close.html) que cierra el objeto *figure* activo o el objeto *figure* con el identificador especificado.
#
#
# ### Gestión sugerida de los objetos *figure*.
#
# Es importante tener en cuenta que el uso de estos métodos puede variar dependiendo del entorno de ejecución y la configuración de *Matplotlib*. Para evitar problemas de gestión de los objetos *figure*, es recomendable crear sólo un objeto *figure* de forma explícita y luego trazar los gráficos dentro del objeto *axes* asociado a ese objeto *figure*.

# %% [markdown]
# ## Los objetos *axes*.
#
# Los objetos *axes* son instancias de la clase ```matplotlib.axes.Axes``` y son los que realmente contienen los gráficos y las visualizaciones. Un objeto *figure* puede contener uno o más objetos *axes*, pero cada objeto *axes* solo puede pertenecer a un objeto *figure*.
#
# Los objetos *axes* son los que realmente contienen los gráficos y las visualizaciones, por lo que es necesario crear un objeto *axes* dentro de un objeto *figure* para poder trazar cualquier gráfico o visualización.
#
# Por convención se le asigna el nombre ```ax``` al objeto *axes*.
#
# ### Los objetos *artist*.
#
# Los objetos *artist* son instancias de la clase ```matplotlib.artist.Artist``` y son los que realmente representan los elementos gráficos como líneas, puntos, texto, etc.
#
# Por lo general no es necesario interactuar directamente con los objetos *artist*, ya que la mayoría de las funciones de *Matplotlib* se encargan de crear y gestionar estos objetos de forma automática.
#
# https://matplotlib.org/stable/api/artist_api.html#matplotlib.artist.Artist

# %% [markdown]
# ### Métodos para trazar gráficos y visualizaciones en un objeto *axes*.
#
# Los objetos *axes* tienen una gran variedad de métodos para trazar gráficos y visualizaciones, como por ejemplo:
#
# * [`ax.plot()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.plot.html) para trazar gráficos de líneas.
# * [`ax.scatter()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.scatter.html) para trazar gráficos de dispersión.
# * [`ax.bar()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.bar.html) para trazar gráficos de barras.
# * [`ax.hist()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html) para trazar histogramas.
# * [`ax.imshow()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.imshow.html) para trazar imágenes.
# * [`ax.contour()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.contour.html) para trazar gráficos de contorno.
#
# Además de estos métodos, los objetos *axes* también tienen métodos para personalizar los gráficos y las visualizaciones, como por ejemplo:
#
# * [`ax.set_title()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_title.html) para establecer el título del gráfico.
# * [`ax.set_xlabel()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xlabel.html) para establecer la etiqueta del eje $x$.
# * [`ax.set_ylabel()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_ylabel.html) para establecer la etiqueta del eje $y$.
# * [`ax.set_xlim()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xlim.html) para establecer los límites del eje $x$.
# * [`ax.set_ylim()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_ylim.html) para establecer los límites del eje $y$.
# * [`ax.legend()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.legend.html) para mostrar la leyenda del gráfico.
#
# La lista de métodos para trazar gráficos y visualizaciones en un objeto *axes* es muy extensa, por lo que se recomienda consultar la documentación oficial de *Matplotlib* para obtener más información sobre los métodos disponibles.
#
# https://matplotlib.org/stable/api/axes_api.html#matplotlib.axes.Axes

# %% [markdown]
# ### Creación de objetos *axes*.
#
# Existen varias formas de crear objetos *axes* en *Matplotlib*, pero la forma más común es utilizando los métodos:
# * ```fig.add_subplot()```, el cual permite crear un objeto *axes* dentro de un objeto *figure* especificando la posición del objeto *axes* dentro de una cuadrícula.
# * ```fig.subplots()```, el cual permite crear una cuadrícula de objetos *axes* dentro de un objeto *figure* especificando el número de filas y columnas de la cuadrícula.

# %% [markdown]
# #### Método ```fig.add_subplot()```.
# El método ```fig.add_subplot()``` permite crear un objeto *axes* dentro de un objeto *figure* especificando la posición del objeto *axes* dentro de una cuadrícula. La sintaxis es la siguiente:
#
# ```
# fig.add_subplot(<nfilas>, <ncols>, <index>, **kwargs)
# ```
# Donde:
# * `<nfilas>` es el número de filas en la cuadrícula.
# * `<ncols>` es el número de columnas en la cuadrícula.
# * `<index>` es el índice del objeto *axes* dentro de la cuadrícula, comenzando desde 1 y contando de izquierda a derecha y de arriba hacia abajo.
# * `**kwargs` son argumentos adicionales que se pasan al objeto *axes*.

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda:
#     * Creará al objeto `fig`.
#     * Crearáal objeto `ax` utilizando el método `fig.add_subplot()`.
#     * Trazará un gráfico de líneas utilizando el método `ax.plot()` con los arreglos `x` y `y` definidos previamente para los ejes $x$ e $y$ respectivamente.
#     * Se definirá el título del gráfico utilizando el método `ax.set_title()`.
#     * Se definirá la etiqueta del eje $x$ utilizando el método `ax.set_xlabel()`
#     * Se definirá la etiqueta del eje $y$ utilizando el método `ax.set_ylabel()`.
#     * Se definirá un recuadro de leyenda utilizando el método `ax.legend()`.

# %%
fig = plt.figure(figsize=(8, 6), dpi=100)
ax = fig.add_subplot(1, 1, 1)
ax.plot(x, y)
ax.set_title('Parabola')
ax.set_xlabel('x')
ax.set_ylabel('y and z')
ax.legend(['y = x^2 - 2x'])

# %% [markdown]
# * La siguiente celda creará una figura con 2 *subplots* apilados verticalmente.

# %%
fig = plt.figure(figsize=(6, 8), dpi=100)
ax1 = fig.add_subplot(2, 1, 1) # 2 filas, 1 columna, primer subplot
ax1.plot(x, y)
ax1.set_title('Parabola')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.legend(['y = x^2 - 2x'])
ax2 = fig.add_subplot(2, 1, 2) # 2 filas, 1 columna, segundo subplot
ax2.plot(x, z)
ax2.set_title('Parabola con seno')
ax2.set_xlabel('x')
ax2.set_ylabel('z')
ax2.legend(['z = x^2 * (1 + sin(x))'])

# %% [markdown]
# #### El método ```fig.subplots()```.
# El método ```fig.subplots()``` permite crear una cuadrícula de objetos *axes* dentro de un objeto *figure* especificando el número de filas y columnas de la cuadrícula. La sintaxis es la siguiente:
# ```
# fig.subplots(nrows, ncols)
# ```
# Donde:
# * `nrows` es el número de filas en la cuadrícula.
# * `ncols` es el número de columnas en la cuadrícula.
# El método `fig.subplots()` devuelve una tupla que contiene los objetos *axes* creados. Si se crea una cuadrícula de un solo objeto *axes*, el método devolverá directamente el objeto *axes* en lugar de una tupla.
#
# Cada objeto *axes* creado con el método `fig.subplots()` se puede personalizar de forma independiente utilizando los métodos de los objetos *axes* descritos anteriormente.

# %% [markdown]
# #### Posición de los subplots.
#
# El objeto *ax* creado con el método subplot contiene un arreglo de objetos *axes* que corresponden a cada uno de los subplots creados. Para acceder a cada uno de los objetos *axes* individuales, se puede utilizar la indexación del arreglo.
#
# ```
# ax[<fila>, <columna>]
# ```
# Donde `<fila>` es el índice de la fila del subplot y `<columna>` es el índice de la columna del subplot. La indexación comienza desde 0, por lo que el primer subplot se encuentra en la posición `[0, 0]`, el segundo subplot en la posición `[0, 1]`, y así sucesivamente.
#
# * En caso de que la cuadrícula sea de una sola fila o una sola columna, el método `fig.subplots()` devolverá un arreglo unidimensional de objetos *axes* en lugar de una tupla, por lo que la indexación se realizará utilizando un solo índice.
#
# * En caso de que la cuadrícula sea de un solo subplot, el método `fig.subplots()` devolverá directamente el objeto *axes* en lugar de una tupla, por lo que no será necesario utilizar la indexación para acceder al objeto *axes*.

# %% [markdown]
# **Ejemplos**:

# %% [markdown]
# * La siguiente celda creará un objeto `fig` y una cuadrícula de objetos `ax` utilizando el método `fig.subplots()` con una columna de dos filas.
# * Trazará un gráfico de líneas en cada objeto `ax` utilizando los arreglos `x`, `y` y `z` definidos previamente para los ejes $x$ e $y$ respectivamente.
# * Finalmente, se definirán los títulos, etiquetas de los ejes y leyendas para cada gráfico utilizando los métodos correspondientes de los objetos `ax`.

# %%
fig = plt.figure(figsize=(8, 6), dpi=100)
ax = fig.subplots(2, 1)
ax[0].plot(x, y)
ax[0].set_title('Parabola')
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
ax[0].legend(['y = x^2 - 2x'])  
ax[1].plot(x, z)
ax[1].set_title('Parabola with Sine')
ax[1].set_xlabel('x')
ax[1].set_ylabel('z')
ax[1].legend(['z = x^2 * (1 + sin(x))'])

# %% [markdown]
# * La siguiente celda creará una figura con 2 columnas y una fila de subplots.

# %%
fig = plt.figure(figsize=(8, 6), dpi=100)
ax = fig.subplots(1, 2)
ax[0].plot(x, y)
ax[0].set_title('Parabola')
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
ax[0].legend(['y = x^2 - 2x'])  
ax[1].plot(x, z)
ax[1].set_title('Parabola with Sine')
ax[1].set_xlabel('x')
ax[1].set_ylabel('z')
ax[1].legend(['z = x^2 * (1 + sin(x))'])

# %% [markdown]
# * La siguiente celda creará una figura que contiene 2 filas y 2 columnas de subplots.

# %%
fig = plt.figure(figsize=(8, 6), dpi=100)
ax = fig.subplots(2, 2)
ax[0, 0].plot(x, y)
ax[0, 0].set_title('Parabola')
ax[0, 0].set_xlabel('x')
ax[0, 0].set_ylabel('y')
ax[0, 0].legend(['y = x^2 - 2x'])  
ax[0, 1].plot(x, z)
ax[0, 1].set_title('Parabola with Sine')
ax[0, 1].set_xlabel('x')
ax[0, 1].set_ylabel('z')
ax[0, 1].legend(['z = x^2 * (1 + sin(x))'])
ax[1, 0].plot(x, y, x, z)
ax[1, 0].set_title('Parabola and Parabola with Sine')
ax[1, 0].set_xlabel('x')
ax[1, 0].set_ylabel('y and z')
ax[1, 0].legend(['y = x^2 - 2x', 'z = x^2 * (1 + sin(x))'])

# %% [markdown]
# ## Visualización con el objeto `plt`.
#
# El objeto `plt` es una instancia de la clase `matplotlib.pyplot` y es el módulo principal de *Matplotlib* para trazar gráficos y visualizaciones.
#
# El objeto `plt` proporciona una interfaz de alto nivel para crear gráficos y visualizaciones de forma rápida y sencilla, sin necesidad de interactuar directamente con los objetos *figure* y *axes*, los cuales son gestionados automáticamente por `plt`.
#
# ```
# plt.plot(<pares de datos>, **kwargs)
# ```
# Donde:
# * `<pares de datos>` son los datos que se desean trazar, los cuales pueden ser proporcionados como listas, arreglos de *NumPy* o pandas, o como objetos *Series* de pandas.
# * `**kwargs` son argumentos adicionales que se pasan a la función de trazado, como por ejemplo el color, el estilo de línea, el ancho de línea, etc.
#
# La documentación oficial de *Matplotlib* proporciona una lista completa de los métodos disponibles en el objeto `plt` para trazar gráficos y visualizaciones, así como los argumentos adicionales que se pueden utilizar para personalizar los gráficos.
#
# https://matplotlib.org/stable/api/pyplot_api.html#module-matplotlib.pyplot
#
# El objeto `plt` comparte muchas funciones con los objetos *axes*, por lo que es importante tener en cuenta que algunas funciones de `plt` pueden afectar a todos los objetos *axes* existentes, mientras que otras funciones solo afectarán al objeto *axes* activo.
#
# Con fines didácticos, se recomienda utilizar el objeto `plt` para trazar gráficos y visualizaciones de forma rápida y sencilla, pero para una mayor personalización y control sobre los gráficos, es recomendable utilizar los objetos *figure* y *axes* directamente.

# %% [markdown]
# ### El método ```plt.title()```.
#
# Este método permite definir un títlulo para la figura, el cual se mostrará en la parte superior del gráfico. La sintaxis es la siguiente:
#
# ```
# plt.title(<titulo>)
# ```
#
# Donde:
#
# * ```<titulo>``` es una cadena de caracteres.

# %% [markdown]
# **Eejmplo:**

# %% [markdown]
# * La siguiente celda creará una figura con el título ```Pythonista```.

# %%
plt.figure(dpi=50)
plt.title("Pythonista")

# %% [markdown]
# ### El método ```plt.plot()```.
#
# El método ```plt.plot()``` permite crear gráficas de líneas en los ejex $x$ y $y$ utilizando los datos proporcionados. La sintaxis es la siguiente:
#
# ```
# plt.plot(x,y, scalex=<bool>, scaley=<bool>, data=<datos>, **kwargs)
# ```
# Donde:
# * `x` es el conjunto de datos para el eje $x$.
# * `y` es el conjunto de datos para el eje $y$.
# * `scalex` es un valor booleano que indica si se deben escalar los límites del eje $x$ para ajustarse a los datos proporcionados. El valor por defecto es `True`.
# * `scaley` es un valor booleano que indica si se deben escalar los límites del eje $y$ para ajustarse a los datos proporcionados. El valor por defecto es `True`.
# * `data` es un conjunto de datos opcional que se puede utilizar para proporcionar los datos para el eje $x$ y el eje $y$ utilizando nombres de columnas en lugar de pasar los datos directamente como argumentos `x` e `y`.
# * `**kwargs` son argumentos adicionales que se pasan a la función de trazado, como por ejemplo el color, el estilo de línea, el ancho de línea, etc.
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * Las siguientes celdas trazarán gráficas mediante el método ```plt.plot()``` con diversos argumentos.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y)

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='x')

# %% [markdown]
# ### Parámetros del método ```plt.plot()```.

# %% [markdown]
# #### El parámetro ```marker```.
#
# El parámetro ```marker``` permite definir diversos tipos de marcador de puntos.
#
# Algunos de los marcadores disponibles son:
# * `'.'` para puntos.
# * `','` para píxeles.
# * `'o'` para círculos.
# * `'v'` para triángulos hacia abajo.
# * `'^'` para triángulos hacia arriba.
# * `'<'` para triángulos hacia la izquierda.
# * `'>'` para triángulos hacia la derecha.
# * `'1'` para triángulos hacia abajo con una línea vertical.
# * `'2'` para triángulos hacia arriba con una línea vertical.
# * `'3'` para triángulos hacia la izquierda con una línea horizontal.
# * `'4'` para triángulos hacia la derecha con una línea horizontal.
# * `'s'` para cuadrados.
# * `'p'` para pentágonos.
# * `'*'` para estrellas.
# * `'h'` para hexágonos.
# * `'H'` para hexágonos.
# * `'+'` para signos de suma.
# * `'x'` para cruces.
# * `'D'` para diamantes.
# * `'d'` para diamantes.
# * `'|'` para líneas verticales.
# * `'_'` para líneas horizontales.
#
# https://matplotlib.org/stable/api/markers_api.html

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda desplegará la figura con marcadores hexagonales.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='h')

# %% [markdown]
# * La siguiente celda desplegará la figura con marcadores en forma de tache.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='X')

# %% [markdown]
# * La siguiente celda desplegará la figura con marcadores en forma de triángulos hacia abajo.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='1')

# %% [markdown]
# #### El parámetro ```markersize```.
#
# El parámetro ```markersize``` permite definir el tamaño de los marcadores.
#
# La sintaxis es la siguiente:
#
# ```
# plt.plot(x, y, marker=<marcador>, markersize=<tamaño>, **kwargs)
# ```
# Donde:
# * `<marcador>` es el tipo de marcador que se desea utilizar, como por ejemplo `'.'` para puntos, `'o'` para círculos, etc.
# * `<tamaño>` es el tamaño de los marcadores, el cual se puede especificar como un número entero o un número de punto flotante. El valor por defecto es `6`.

# %% [markdown]
# **Ejemplo:**

# %% [markdown]
# * La siguiente celda desplegará la figura con marcadores en forma de hexágono y tamaño `10`.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='h', markersize=10)

# %% [markdown]
# #### El parámetro ```markerfacecolor```.
#
# El parámetro ```markerfacecolor``` permite definir el color de los marcadores. Los marcadores pueden ser definidos utilizando nombres de colores, códigos hexadecimales, códigos RGB o códigos RGBA.
#
# ```
# plt.plot(x, y, marker=<marcador>, markerfacecolor=<color>, **kwargs)
# ```
# Donde:
# * `<marcador>` es el tipo de marcador que se desea utilizar, como por ejemplo `'.'` para puntos, `'o'` para círculos, etc.
# * `<color>` es el color que se desea utilizar para los marcadores, el cual se puede especificar utilizando nombres de colores, códigos hexadecimales, códigos RGB o códigos RGBA. El valor por defecto es `'auto'`, lo que significa que se utilizará el mismo color que la línea del gráfico.
#
# Los códigos de color pueden ser consultados en el siguiente vínculo:
#
# * https://matplotlib.org/stable/gallery/color/named_colors.html

# %% [markdown]
# **Ejemplo:**

# %% [markdown]
# * La siguiente celda desplegará marcadores hexagonales de tamaño `5` en color definido por "red" (rojo).

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='h', markersize=5, markerfacecolor="red")

# %% [markdown]
# #### El parámetro ```color```.
#
# El parámetro ```color``` permite definir el color de la línea del gráfico. Al igual que con los marcadores, el color de la línea se puede especificar utilizando nombres de colores, códigos hexadecimales, códigos RGB o códigos RGBA.
#
# ```
# plt.plot(x, y, color=<color>, **kwargs)
# ```
# Donde:
# * `<color>` es el color que se desea utilizar para la línea del gráfico, el cual se puede especificar utilizando nombres de colores, códigos hexadecimales, códigos RGB o códigos RGBA. El valor por defecto es `'blue'`.
#
# Los códigos de color pueden ser consultados en el siguiente vínculo:
# * https://matplotlib.org/stable/gallery/color/named_colors.html

# %% [markdown]
# **Ejemplo:**

# %% [markdown]
# * La siguiente celda desplegará la figura cuyo trazo corresponde al color ```'salmon'```.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, color='salmon', marker='h', markersize=5, markerfacecolor="blue")

# %% [markdown]
# #### El parámetro ```linestyle```.
#
#
# El parámetro ```linestyle``` permite definir el estilo de las líneas del trazo.
# ```
# plt.plot(x, y, linestyle=<estilo>, **kwargs)
# ```
# Donde:
# * `<estilo>` es el estilo de línea que se desea utilizar, el cual puede ser especificado utilizando los siguientes valores:
#     * `'-'` para líneas sólidas.
#     * `'--'` para líneas discontinuas.
#     * `'-.'` para líneas mixtas.
#     * `':'` para líneas punteadas.
#
# Los diversos tipos de línea pueden ser consultados en:
#
# * https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html

# %% [markdown]
# **Ejemplo:**

# %% [markdown]
# * La siguiente celda desplegará un trazo con líneas punteadas definidas por ```':'```.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, linestyle=':')

# %% [markdown]
# #### El parámetro ```linewidth```.
# El parámetro ```linewidth``` permite definir el ancho de las líneas del trazo.
#
# ```
# plt.plot(x, y, linewidth=<ancho>, **kwargs)
# ```
# Donde:
# * `<ancho>` es el ancho de las líneas del trazo, el cual se puede especificar como un número entero o un número de punto flotante. El valor por defecto es `1.5`.

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * Las siguiente celda trazará una línea con ancho igual a `1`.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, linewidth=1)

# %% [markdown]
# *

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, linewidth=3)

# %% [markdown]
# #### El parámetro ```label```.

# %% [markdown]
#  El parámetro ```label``` de ```plt.plot()``` permite asignarle una descripción a cada trazo.

# %% [markdown]
# ### El método ```plt.legend()```.
#
# Este método inserta una tabla presentando una representación de tipo y color de cada tazo junto con el texto ligado al parámetro ```label```de cada trazo.
#
# La documentación completa del método ```plt.legend()```.
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda desplegará una figura con una tabla creada por ```plt.legend()``` en la parte superior y al centro.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y, label='función 1')
plt.plot(x, z, label='función 2')
plt.legend()

# %% [markdown]
# * La siguiente celda desplegará una figura con una tabla creada por ```plt.legend()``` en la parte inferior izquierda.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y, label='función 1')
plt.plot(x, z, label='función 2')
plt.legend(loc="lower left")

# %% [markdown]
# ## Etiquetas de ejes.

# %% [markdown]
# Las etiquetas de los ejes pueden ser definidas por los métodos.
#
# * ```plt.xlabel()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html
# * ```plt.ylabel()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda trazará una imagen con las etiquetas:
#  * ```Eje de las x``` para el eje $x$.
#  * ```f(x)``` para el eje $y$.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y)

# %% [markdown]
# ## Límites de ejes.

# %% [markdown]
# Es posible definir la magnitud de los ejes de una figura, dentro de los cuales será realizado el trazo de ```plt.plot()```.
#
# Los límites de los ejes se defienen mediante los métodos:
#
# * ```plt.xlim()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlim.html
# * ```plt.ylim()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylim.html

# %% [markdown]
# **Ejemplo:**

# %% [markdown]
# * La siguiente celda desplegará trazos dentro de los límites definidos por:
#  * ```plt.xlim(0, 50)```
#  * ```plt.ylim(0, 500)```

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.xlim(0, 50)
plt.ylim(0, 500)
plt.plot(x, y)

# %% [markdown]
# ## El método ```plt.margins()```.

# %% [markdown]
# El método ```plt.margins()``` permite definir los márgenes entre los ejes.
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.margins.html

# %% [markdown]
# **Ejemplos:**

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y)
plt.margins(0.5)

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y)
plt.margins(0.1, 0)

# %% [markdown]
# ## Rejillas.

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.grid.html

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Subplots.

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html#examples-using-matplotlib-pyplot-subplot

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 2, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 2, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z * y, label='función combinada')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Guardado de imagen.

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.savefig('grafica.png')

# %% [markdown]
# ## Estilos.

# %% [markdown]
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
#
# https://matplotlib.org/stable/tutorials/introductory/customizing.html#using-style-sheets
#
# https://matplotlib.org/stable/tutorials/colors/colors.html#sphx-glr-tutorials-colors-colors-py

# %%
mpl.style.available

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.savefig('grafica.png')

# %%
mpl.style.use('ggplot')
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.savefig('grafica.png')

# %%
mpl.style.use('dark_background')
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.savefig('grafica.png')

# %%
mpl.style.use('default')

# %% [markdown]
# ## Imágenes con *Matplotlib*.

# %% [markdown]
# * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imread.html

# %%
imagen = plt.imread('img/pythonista.png')

# %%
imagen

# %% [markdown]
# * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html

# %%
# %matplotlib inline

# %%
plt.imshow(imagen)

# %%
plt.axis('off')

# %%
plt.imshow(imagen)

# %% [markdown]
# * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imsave.html

# %%
plt.imsave('imagen.jpg', imagen)

# %%
imagen.shape

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2017-2026.</p>

# %% [markdown]
# [![img/pythonista.png](img/pythonista.png)](https://www.pythonista.io)

# %% [markdown]
# # Elementos de un gráfico de *Matplotlib*.

# %% [markdown]
# https://matplotlibguide.readthedocs.io/en/latest/Matplotlib/basic.html

# %%
import matplotlib as mpl
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Preliminares.

# %% [markdown]
# ### Ajuste de la *notebook* para ejecución del modo interactivo.
#
# La interfaz de *IPython* permite desplegar figuras e imágenes generadas por *Matplotlib* mediante el siguiete comando mágico.
#
# ```
# %matplotlib notebook
# ```
#
# https://ipython.readthedocs.io/en/stable/interactive/magics.html#magic-matplotlib

# %%
# %matplotlib notebook

# %% [markdown]
# ### Datos ilustrativos.

# %% [markdown]
# * La siguienten celda definirá al arregl;o ```x``` el cual contiene un espacio lineal con ```50```segmentos que van de  ```-50``` a ```50```.

# %%
x = np.linspace(-50, 50, 50)
x
# Out:
# array([-50.        , -47.95918367, -45.91836735, -43.87755102,
#        -41.83673469, -39.79591837, -37.75510204, -35.71428571,
#        -33.67346939, -31.63265306, -29.59183673, -27.55102041,
#        -25.51020408, -23.46938776, -21.42857143, -19.3877551 ,
#        -17.34693878, -15.30612245, -13.26530612, -11.2244898 ,
#         -9.18367347,  -7.14285714,  -5.10204082,  -3.06122449,
#         -1.02040816,   1.02040816,   3.06122449,   5.10204082,
#          7.14285714,   9.18367347,  11.2244898 ,  13.26530612,
#         15.30612245,  17.34693878,  19.3877551 ,  21.42857143,
#         23.46938776,  25.51020408,  27.55102041,  29.59183673,
#         31.63265306,  33.67346939,  35.71428571,  37.75510204,
#         39.79591837,  41.83673469,  43.87755102,  45.91836735,
#         47.95918367,  50.        ])

# %% [markdown]
# * La siguiente celda definirá al arreglo ```y```, el cual contienen el resultado de la operación  ```(x ** 2) - (2 * x)```.

# %%
y = (x ** 2) - (2 * x)
y
# Out:
# array([ 2.60000000e+03,  2.39600167e+03,  2.20033319e+03,  2.01299459e+03,
#         1.83398584e+03,  1.66330696e+03,  1.50095793e+03,  1.34693878e+03,
#         1.20124948e+03,  1.06389005e+03,  9.34860475e+02,  8.14160766e+02,
#         7.01790920e+02,  5.97750937e+02,  5.02040816e+02,  4.14660558e+02,
#         3.35610162e+02,  2.64889629e+02,  2.02498959e+02,  1.48438151e+02,
#         1.02707205e+02,  6.53061224e+01,  3.62349021e+01,  1.54935444e+01,
#         3.08204915e+00, -9.99583507e-01,  3.24864640e+00,  1.58267389e+01,
#         3.67346939e+01,  6.59725115e+01,  1.03540192e+02,  1.49437734e+02,
#         2.03665140e+02,  2.66222407e+02,  3.37109538e+02,  4.16326531e+02,
#         5.03873386e+02,  5.99750104e+02,  7.03956685e+02,  8.16493128e+02,
#         9.37359434e+02,  1.06655560e+03,  1.20408163e+03,  1.34993753e+03,
#         1.50412328e+03,  1.66663890e+03,  1.83748438e+03,  2.01665973e+03,
#         2.20416493e+03,  2.40000000e+03])

# %% [markdown]
# * La siguiente celda definirá al arreglo ```z```, el cual contienen el resultado de la operación  ```x ** 2 * (1 +  np.sin(x))```.

# %%
z = x ** 2 * (1 +  np.sin(x))
z
# Out:
# array([3.15593713e+03, 4.00558062e+03, 1.39106012e+02, 2.12653231e+03,
#        3.21938361e+03, 2.14091082e+02, 1.34567832e+03, 2.44324881e+03,
#        2.57041093e+02, 7.85456516e+02, 1.72341281e+03, 2.56658905e+02,
#        4.10920502e+02, 1.09926665e+03, 2.14269827e+02, 1.83209913e+02,
#        6.01133451e+02, 1.42648410e+02, 6.27497574e+01, 2.48691671e+02,
#        6.42015821e+01, 1.23658972e+01, 5.01104064e+01, 8.61876814e+00,
#        1.53767628e-01, 1.92869801e+00, 1.01234226e+01, 1.95123460e+00,
#        8.96749192e+01, 1.04478135e+02, 3.28667168e+00, 2.89186936e+02,
#        3.25906359e+02, 6.99118855e-01, 5.68560183e+02, 7.04097520e+02,
#        2.35767195e+00, 8.90620522e+02, 1.26145855e+03, 2.79407892e+01,
#        1.21579296e+03, 2.01076399e+03, 1.07771602e+02, 1.50521714e+03,
#        2.95333916e+03, 2.81241126e+02, 1.72394666e+03, 4.07788691e+03,
#        5.94585981e+02, 1.84406287e+03])

# %% [markdown]
# * La siguiente celda trazará una gráfica usando al arreglo ```x``` como el conjunto de datos paras el eje $x$ y ```y``` y ```z``` como funciones de $x$ que serán representadas en el eje $y$ utilizando el método ```plt.plot()```. Se utulizará los parámetros por defecto.

# %%
plt.plot(x, y, x, z)
# Out:
# <img src="data:image/png;base64,..." width="639.4833333333333">
# [<matplotlib.lines.Line2D at 0x7f08384c6460>,
#  <matplotlib.lines.Line2D at 0x7f08384c64c0>]

# %% [markdown]
# ## La clase ```plt.Figure```.

# %% [markdown]
# Los elementos base para el trazado de gráficos con *Matplotlib* son los objetos ```figure```, los cuales son instancias de la clase ```matplotlib.figure.Figure```.
#
# https://matplotlib.org/stable/api/figure_api.html#matplotlib.figure.Figure

# %% [markdown]
# ### La función ```plt.figure()```.
#
# Para poder crear un objeto ```fiugre``` se utiliza el métodos ```plt.figure```.
#
#
# ```
# plt.figure(num=<id>, figsize=<tamaño>, dpi=<resolución>)
# ```
#
# Donde:
#
# * ```<id>``` es un identificador único del objeto *figure*. En caso de no definirse, el identificador será un número que iniciará en ```1``` e irá incrementándose de 1 en 1.
# * ```<tamaño>``` es una tupla de dos elementos cuy primer elemento define el ancho y el segundo la altura de la figura.
# * ```<resolución>``` que corresponde al número de *dpi* de la figura.
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda creará una figura de resolución de ```50 dpi```.

# %%
fig = plt.figure(dpi=50, figsize=(15, 7))
print(type(fig))
# Out:
# <img src="data:image/png;base64,..." width="749.8666666666667">
# <class 'matplotlib.figure.Figure'>

# %% [markdown]
# ## #El método ```plt.title()```.
#
# Este método permite definir un títlulo para la figura.
#
# ```
# plt.title(<titulo>)
# ```
#
# Donde:
#
# * ```<titulo>``` es una cadena de caracteres.

# %% [markdown]
# **Eejmplo:**

# %% [markdown]
# * La siguiente celda creará una figura con el título ```Pythonista```.

# %%
plt.figure(dpi=50)
plt.title("Pythonista")
# Out:
# <img src="data:image/png;base64,..." width="320.04999999999995">
# Text(0.5, 1.0, 'Pythonista')

# %% [markdown]
# ## El método  ```plt.plot()```.

# %% [markdown]
# El objeto ```plt``` cuenta con una gran biblioteca de herramientas que permiten crear gráficos y visualizaciones. El método    ```plt.plot()``` permite crear gráficas de líneas en los ejex $x$ y $y$.
#
# ```
# plt.plot(x,y, scalex=<bool>, scaley=<bool>, data=<datos>, **kwargs)
# ```
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * Las siguientes celdas trazarán gráficas mediante el método ```plt.plot()``` con diversos argumentos.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y)

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='x')

# %% [markdown]
# ### Parámetros del método ```plt.plot()```.

# %% [markdown]
# #### El parámetro ```marker```.
#
# El parámetro ```marker``` permite deifnir diversos tipos de marcador de puntos.
#
# https://matplotlib.org/stable/api/markers_api.html

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda desplegará la figura con marcadores hexagonales.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='h')
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %% [markdown]
# * La siguiente celda desplegará la figura con marcadores en forma de tache.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='X')
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='1')
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %% [markdown]
# #### El parámetro ```markersize```.
#
# El parámetro ```marker``` permite deifnir el tamaño de los marcadores.

# %% [markdown]
# **Ejemplo:**

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='h', markersize=10)
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %% [markdown]
# #### El parámetro ```markerfacecolor```.
#
# El parámetro ```marker``` permite deifnir el color de los marcadores.
#
# Los códigos de color pueden ser consultados en eol siguiente nvínculo:
#
# * https://matplotlib.org/stable/gallery/color/named_colors.html

# %% [markdown]
# **Ejemplo:**

# %% [markdown]
# * La siguiente celda desplegará marcadores en color rojo.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='h', markersize=5, markerfacecolor="red")
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %% [markdown]
# #### El parámetro ```color```.
#
# El parámetro ```color``` permite definir el color de las líneas del trazo.

# %% [markdown]
# **Ejemplo:**

# %% [markdown]
# * La siguiente celda desplegará la figura cuyo trazo corresponde al color ```'salmon'```.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, color='salmon', marker='h', markersize=5, markerfacecolor="blue")
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %% [markdown]
# #### El parámetro ```linestyle```.
#
#
# El parámetro ```linestyle``` permite definir el estilo de las líneas del trazo.
#
# Los diversos tipos de línea pueden ser consultados en:
#
# * https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html

# %% [markdown]
# **Ejemplo:**

# %% [markdown]
# * La siguiente celda desplegará un trazo con líneas punteadas definidas por ```':'```.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, linestyle=':')
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %% [markdown]
# #### El parámetro ```linewidth```.
#
# El parámetro ```linewidth``` permite definir el ancho de de las líneas del trazo.

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * Las siguientes celdas trazarán líneas con diversos ancho.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, linewidth=1)
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, linewidth=3)
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %% [markdown]
# #### El parámetro ```label```.

# %% [markdown]
#  El parámetro ```label``` de ```plt.plot()``` permite asignarle una descripción a cada trazo.

# %% [markdown]
# ### El método ```plt.legend()```.
#
# Este método inserta una tabla presentando una representación de tipo y color de cada tazo junto con el texto ligado al parámetro ```label```de cada trazo.
#
# La documentación completa del método ```plt.legend()```.
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda desplegará una figura con una tabla creada por ```plt.legend()``` en la parte superior y al centro.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y, label='función 1')
plt.plot(x, z, label='función 2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %% [markdown]
# * La siguiente celda desplegará una figura con una tabla creada por ```plt.legend()``` en la parte inferior izquierda.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y, label='función 1')
plt.plot(x, z, label='función 2')
plt.legend(loc="lower left")
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %% [markdown]
# ## Etiquetas de ejes.

# %% [markdown]
# Las etiquetas de los ejes pueden ser definidas por los métodos.
#
# * ```plt.xlabel()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html
# * ```plt.ylabel()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda trazará una imagen con las etiquetas:
#     * ```Eje de las x``` para el eje $x$.
#     * ```f(x)``` para el eje $y$.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %% [markdown]
# ## Límites de ejes.

# %% [markdown]
# Es posible definir la magnitud de los ejes de una figura, dentro de los cuales será realizado el trazo de ```plt.plot()```.
#
# Los límites de los ejes se defienen mediante los métodos:
#
# * ```plt.xlim()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlim.html
# * ```plt.ylim()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylim.html

# %% [markdown]
# **Ejemplo:**

# %% [markdown]
# * La siguiente celda desplegará trazos dentro de los límites definidos por:
#     * ```plt.xlim(0, 50)```
#     * ```plt.ylim(0, 500)```

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.xlim(0, 50)
plt.ylim(0, 500)
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="511.8333333333333">

# %% [markdown]
# ## El método ```plt.margins()```.

# %% [markdown]
# El método ```plt.margins()``` permite definir los márgenes entre los ejes.
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.margins.html

# %% [markdown]
# **Ejemplos:**

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y)
plt.margins(0.5)

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y)
plt.margins(0.1, 0)

# %% [markdown]
# ## Rejillas.

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.grid.html

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Subplots.

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html#examples-using-matplotlib-pyplot-subplot

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 2, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 2, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z * y, label='función combinada')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Guardado de imagen.

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.savefig('grafica.png')

# %% [markdown]
# ## Estilos.

# %% [markdown]
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
#
# https://matplotlib.org/stable/tutorials/introductory/customizing.html#using-style-sheets
#
# https://matplotlib.org/stable/tutorials/colors/colors.html#sphx-glr-tutorials-colors-colors-py

# %%
mpl.style.available

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.savefig('grafica.png')

# %%
mpl.style.use('ggplot')
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.savefig('grafica.png')

# %%
mpl.style.use('dark_background')
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.savefig('grafica.png')

# %%
mpl.style.use('default')

# %% [markdown]
# ## Imágenes con *Matplotlib*.

# %% [markdown]
# * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imread.html

# %%
imagen = plt.imread('img/pythonista.png')

# %%
imagen

# %% [markdown]
# * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html

# %%
# %matplotlib inline

# %%
plt.imshow(imagen)

# %%
plt.axis('off')

# %%
plt.imshow(imagen)

# %% [markdown]
# * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imsave.html

# %%
plt.imsave('imagen.jpg', imagen)

# %%
imagen.shape

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2017-2026.</p>

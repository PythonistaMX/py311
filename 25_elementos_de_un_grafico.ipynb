# %% [markdown]
# [![img/pythonista.png](img/pythonista.png)](https://www.pythonista.io)

# %% [markdown]
# # Elementos de un gráfico de *Matplotlib*.

# %% [markdown]
# https://matplotlibguide.readthedocs.io/en/latest/Matplotlib/basic.html

# %%
# %matplotlib inline
import matplotlib as mpl
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Preliminares.

# %% [markdown]
# ### Ajuste de la *notebook* para ejecución del modo interactivo.
#
# La interfaz de *IPython* permite desplegar figuras e imágenes generadas por *Matplotlib* mediante el siguiete comando mágico.
#
# ```
# %matplotlib notebook
# ```
#
# https://ipython.readthedocs.io/en/stable/interactive/magics.html#magic-matplotlib

# %%
# %matplotlib notebook

# %% [markdown]
# ### Datos ilustrativos.

# %% [markdown]
# * La siguienten celda definirá al arregl;o ```x``` el cual contiene un espacio lineal con ```50```segmentos que van de  ```-50``` a ```50```.

# %%
x = np.linspace(-50, 50, 50)

# %% [markdown]
# * La siguiente celda definirá al arreglo ```y```, el cual contienen el resultado de la operación  ```(x ** 2) - (2 * x)```.

# %%
y = (x ** 2) - (2 * x)
y
# Out:
# array([ 2.60000000e+03,  2.39600167e+03,  2.20033319e+03,  2.01299459e+03,
#         1.83398584e+03,  1.66330696e+03,  1.50095793e+03,  1.34693878e+03,
#         1.20124948e+03,  1.06389005e+03,  9.34860475e+02,  8.14160766e+02,
#         7.01790920e+02,  5.97750937e+02,  5.02040816e+02,  4.14660558e+02,
#         3.35610162e+02,  2.64889629e+02,  2.02498959e+02,  1.48438151e+02,
#         1.02707205e+02,  6.53061224e+01,  3.62349021e+01,  1.54935444e+01,
#         3.08204915e+00, -9.99583507e-01,  3.24864640e+00,  1.58267389e+01,
#         3.67346939e+01,  6.59725115e+01,  1.03540192e+02,  1.49437734e+02,
#         2.03665140e+02,  2.66222407e+02,  3.37109538e+02,  4.16326531e+02,
#         5.03873386e+02,  5.99750104e+02,  7.03956685e+02,  8.16493128e+02,
#         9.37359434e+02,  1.06655560e+03,  1.20408163e+03,  1.34993753e+03,
#         1.50412328e+03,  1.66663890e+03,  1.83748438e+03,  2.01665973e+03,
#         2.20416493e+03,  2.40000000e+03])

# %% [markdown]
# * La siguiente celda definirá al arreglo ```z```, el cual contienen el resultado de la operación  ```x ** 2 * (1 +  np.sin(x))```.

# %%
z = x ** 2 * (1 +  np.sin(x))
y
# Out:
# array([ 2.60000000e+03,  2.39600167e+03,  2.20033319e+03,  2.01299459e+03,
#         1.83398584e+03,  1.66330696e+03,  1.50095793e+03,  1.34693878e+03,
#         1.20124948e+03,  1.06389005e+03,  9.34860475e+02,  8.14160766e+02,
#         7.01790920e+02,  5.97750937e+02,  5.02040816e+02,  4.14660558e+02,
#         3.35610162e+02,  2.64889629e+02,  2.02498959e+02,  1.48438151e+02,
#         1.02707205e+02,  6.53061224e+01,  3.62349021e+01,  1.54935444e+01,
#         3.08204915e+00, -9.99583507e-01,  3.24864640e+00,  1.58267389e+01,
#         3.67346939e+01,  6.59725115e+01,  1.03540192e+02,  1.49437734e+02,
#         2.03665140e+02,  2.66222407e+02,  3.37109538e+02,  4.16326531e+02,
#         5.03873386e+02,  5.99750104e+02,  7.03956685e+02,  8.16493128e+02,
#         9.37359434e+02,  1.06655560e+03,  1.20408163e+03,  1.34993753e+03,
#         1.50412328e+03,  1.66663890e+03,  1.83748438e+03,  2.01665973e+03,
#         2.20416493e+03,  2.40000000e+03])

# %% [markdown]
# * La siguiente celda trazará una gráfica usando al arreglo ```x``` como el conjunto de datos paras el eje $x$ y ```y``` y ```z``` como funciones de $x$ que serán representadas en el eje $y$ utilizando el método ```plt.plot()```. Se utulizará los parámetros por defecto.

# %%
plt.plot(x, y, x, z)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x7faf63d55390>,
#  <matplotlib.lines.Line2D at 0x7faf63d553f0>]

# %% [markdown]
# ## La clase ```plt.Figure```.

# %% [markdown]
# Los elementos base para el trazado de gráficos con *Matplotlib* son los objetos ```figure```, los cuales son instancias de la clase ```matplotlib.figure.Figure```.
#
# https://matplotlib.org/stable/api/figure_api.html#matplotlib.figure.Figure

# %% [markdown]
# ### La función ```plt.figure()```.
#
# Para poder crear un objeto ```fiugre``` se utiliza el métodos ```plt.figure```.
#
#
# ```
# plt.figure(num=<id>, figsize=<tamaño>, dpi=<resolución>)
# ```
#
# Donde:
#
# * ```<id>``` es un identificador único del objeto *figure*. En caso de no definirse, el identificador será un número que iniciará en ```1``` e irá incrementándose de 1 en 1.
# * ```<tamaño>``` es una tupla de dos elementos cuy primer elemento define el ancho y el segundo la altura de la figura.
# * ```<resolución>``` que corresponde al número de *dpi* de la figura.
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguente celda creará una figura de resolución de

# %%
fig = plt.figure(dpi=20, figsize=(10, 5))
print(type(fig))
# Out:
# <img src="data:image/png;base64,..." width="200">
# <class 'matplotlib.figure.Figure'>

# %% [markdown]
# ## #El método ```plt.title()```.
#
# Este método permite definir un títlulo para la figura.

# %%
plt.figure(dpi=50)
plt.title("Pythonista")
# Out:
# <img src="data:image/png;base64,..." width="320">
# Text(0.5, 1.0, 'Pythonista')

# %% [markdown]
# ## El método  ```plt.plot()```.

# %% [markdown]
# El objeto ```plt``` cuenta con una gran biblioteca de herramientas que permiten crear gráficos y visualizaciones. El método    ```plt.plot()``` permite crear gráficas de líneas en los ejex $x$ y $y$.
#
# ```
# plt.plot(x,y, scalex=<bool>, scaley=<bool>, data=<datos>, **kwargs)
# ```
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * Las siguientes celdas trazarán gráficas mediante el método ```plt.plot()``` con diversos argumentos.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y)

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='x')

# %% [markdown]
# ### El parámetro ```marker```.
#
# https://matplotlib.org/stable/api/markers_api.html

# %% [markdown]
# **Ejemplos:**

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='h')
# Out:
# <img src="data:image/png;base64,..." width="512">

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='X')
# Out:
# <img src="data:image/png;base64,..." width="512">

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='1')
# Out:
# <img src="data:image/png;base64,..." width="512">

# %% [markdown]
# ### El parámetro ```markersize```.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='h', markersize=5)
# Out:
# <img src="data:image/png;base64,..." width="512">

# %% [markdown]
# ### El parámetro ```markerfacecolor```.
#
# https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, marker='h', markersize=5, markerfacecolor="red")
# Out:
# <img src="data:image/png;base64,..." width="512">

# %% [markdown]
# ### El parámetro ```color```.

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, color='salmon', marker='h', markersize=5, markerfacecolor="blue")
# Out:
# <img src="data:image/png;base64,..." width="512">

# %% [markdown]
# ### El parámetro ```linestyle```.
#
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.plot(x, y, linestyle=':')
# Out:
# <img src="data:image/png;base64,..." width="512">

# %% [markdown]
# ### El parámetro ```linewidth```.

# %% [markdown]
# https://matplotlib.org/stable/gallery/pyplots/pyplot_formatstr.html

# %% [markdown]
# ## Etiquetas de ejes.

# %% [markdown]
# * ```plt.xlabel()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html
# * ```plt.ylabel()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="512">

# %% [markdown]
# ## Leyendas.

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y, label='función 1')
plt.plot(x, z, label='función 2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="512">

# %% [markdown]
# ## Límites de ejes.

# %% [markdown]
# * ```plt.xlim()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlim.html
# * ```plt.ylim()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylim.html

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.xlim(0, 50)
plt.ylim(0, 500)
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="512">

# %% [markdown]
# ## Márgenes.

# %% [markdown]
# * ```plt.xlim()``` https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.margins.html

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y)
plt.margins(0.5)

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y)
plt.margins(0.1, 0)

# %% [markdown]
# ## Rejillas.

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.grid.html

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Subplots.

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html#examples-using-matplotlib-pyplot-subplot

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 2, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 2, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z * y, label='función combinada')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Guardado de imagen.

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.savefig('grafica.png')

# %% [markdown]
# ## Estilos.

# %% [markdown]
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
#
# https://matplotlib.org/stable/tutorials/introductory/customizing.html#using-style-sheets
#
# https://matplotlib.org/stable/tutorials/colors/colors.html#sphx-glr-tutorials-colors-colors-py

# %%
mpl.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.savefig('grafica.png')
# Out:
# <img src="data:image/png;base64,..." width="512">
# /tmp/ipykernel_42507/1370522307.py:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 1, 1)

# %%
mpl.style.use('ggplot')
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.savefig('grafica.png')
# Out:
# <img src="data:image/png;base64,..." width="512">
# /tmp/ipykernel_42507/3846316016.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 1, 1)

# %%
mpl.style.use('dark_background')
plt.figure(dpi=80)
plt.title("Pythonista")
plt.xlabel('Eje de las x')
plt.ylabel('f(x)')
plt.subplot(2, 1, 1)
plt.plot(x, y, label='función 1')
plt.legend()
plt.grid(True)
plt.subplot(2, 1, 2)
plt.plot(x, z, label='función 2')
plt.legend()
plt.grid(True)
plt.savefig('grafica.png')
# Out:
# <img src="data:image/png;base64,..." width="512">
# /tmp/ipykernel_42507/1285066844.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 1, 1)

# %%
mpl.style.use('default')

# %% [markdown]
# ## Imágenes con *Matplotlib*.

# %% [markdown]
# * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imread.html

# %%
imagen = plt.imread('img/pythonista.png')

# %%
imagen
# Out:
# array([[[0.16470589, 0.14901961, 0.15294118, 0.7921569 ],
#         [0.13725491, 0.12156863, 0.1254902 , 1.        ],
#         [0.13725491, 0.12156863, 0.1254902 , 1.        ],
#         ...,
#         [0.14117648, 0.1254902 , 0.12941177, 0.99215686],
#         [0.13725491, 0.12156863, 0.1254902 , 0.99607843],
#         [0.13725491, 0.12156863, 0.1254902 , 1.        ]],
#
#        [[0.16470589, 0.14901961, 0.15294118, 0.7921569 ],
#         [0.14117648, 0.1254902 , 0.12941177, 1.        ],
#         [0.09803922, 0.08235294, 0.08627451, 1.        ],
#         ...,
#         [0.14901961, 0.11764706, 0.11764706, 0.99215686],
#         [0.14117648, 0.1254902 , 0.13333334, 0.99215686],
#         [0.13725491, 0.12156863, 0.1254902 , 0.99607843]],
#
#        [[0.16862746, 0.15294118, 0.15686275, 0.7882353 ],
#         [0.10588235, 0.09019608, 0.09411765, 1.        ],
#         [0.57254905, 0.5647059 , 0.5647059 , 1.        ],
#         ...,
#         [0.06666667, 0.29411766, 0.3372549 , 0.99607843],
#         [0.14901961, 0.11764706, 0.11764706, 0.99215686],
#         [0.14117648, 0.1254902 , 0.12941177, 0.99215686]],
#
#        ...,
#
#        [[0.21176471, 0.19607843, 0.2       , 0.7411765 ],
#         [0.13333334, 0.11764706, 0.12156863, 1.        ],
#         [0.13725491, 0.12156863, 0.1254902 , 1.        ],
#         ...,
#         [0.13725491, 0.12156863, 0.1254902 , 1.        ],
#         [0.13725491, 0.12156863, 0.1254902 , 1.        ],
#         [0.14509805, 0.12941177, 0.13333334, 0.9843137 ]],
#
#        [[0.16078432, 0.14509805, 0.14901961, 0.8       ],
#         [0.13725491, 0.12156863, 0.1254902 , 1.        ],
#         [0.13725491, 0.12156863, 0.1254902 , 1.        ],
#         ...,
#         [0.14117648, 0.1254902 , 0.12941177, 0.99215686],
#         [0.14117648, 0.1254902 , 0.12941177, 0.99607843],
#         [0.13725491, 0.12156863, 0.1254902 , 1.        ]],
#
#        [[0.16470589, 0.14901961, 0.15294118, 0.7921569 ],
#         [0.13725491, 0.12156863, 0.1254902 , 1.        ],
#         [0.13725491, 0.12156863, 0.1254902 , 1.        ],
#         ...,
#         [0.14117648, 0.1254902 , 0.12941177, 0.99215686],
#         [0.13725491, 0.12156863, 0.1254902 , 0.99607843],
#         [0.13725491, 0.12156863, 0.1254902 , 1.        ]]], dtype=float32)

# %% [markdown]
# * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html

# %%
# %matplotlib inline

# %%
plt.imshow(imagen)

# %%
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imsave.html

# %%
plt.imsave('imagen.jpg', imagen)

# %%
imagen.shape
# Out:
# (147, 150, 4)

# %% [markdown]
# ## Objetos.

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html

# %% [markdown]
# https://matplotlib.org/stable/api/axes_api.html

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.plot(x, z)
ax.grid(True)

# %%
ax.plot(x, z * 2)

# %%
fig

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2022.</p>

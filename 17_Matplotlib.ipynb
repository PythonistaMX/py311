# %% [markdown]
# [![imagenes/pythonista.png](imagenes/pythonista.png)](https://pythonista.io)

# %% [markdown]
# # Visualización de datos con *Pandas*.

# %%
import pandas as pd
import numpy as np

# %%
datos = pd.read_csv('data/datos_filtrados.csv')

# %%
datos

# %%
datos = datos.drop([0, 1])

# %%
datos

# %%
datos = datos.set_index('Año')

# %%
datos.index.name = "Entidad"

# %%
datos

# %%
datos = datos.astype(float)

# %%
datos['2004']

# %%
historico_2004 = datos['2004']

# %%
historico_2004

# %%
historico_2004.plot()

# %%
historico_2004.plot.pie()

# %%
historico_2004.plot.area()

# %%
historico_2004.plot.bar()

# %%
historico_2004.plot.barh()

# %% [markdown]
# #

# %%
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c5959c742314> in <module>
# ----> 1 from matplotlibn import pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlibn'

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2019.</p>

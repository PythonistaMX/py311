# %% [markdown]
# [![imagenes/pythonista.png](imagenes/pythonista.png)](https://pythonista.io)

# %% [markdown]
# Una de las fortalezas de Pandas es su capacidad de extraer información de diversas fuentes de datos.
#
# ## Fromatos:
#
# * CSV
# * TSV
# * JSON
# * SQL
# * HDF5

# %%
# !pip install xlrd

# %%
import pandas as pd

# %% [markdown]
# ## Funciones de lectura de Pandas.

# %%
[item for item in dir(pd) if 'read_' in item]

# %% [markdown]
# ## Métodos de persistencia y almacenamiento de los objetos de Pandas.

# %%
[item for item in dir(pd.DataFrame) if 'to_' in item]

# %%
help(pd.DataFrame.to_feather)

# %% [markdown]
# ## Ilustración de la obtención de datos a partir de un documento XLS.
#
# A continuación se descargará el archivo localizado en https://www.inegi.org.mx/contenidos/temas/economia/cn/itaee/tabulados/ori/ITAEE_2.xlsx

# %%
import urllib.request

# %%
urllib.request.urlretrieve("https://www.inegi.org.mx/contenidos/temas/economia/cn/itaee/tabulados/ori/ITAEE_2.xlsx", "datos.xlsx")

# %%
# %ls datos.xlsx

# %%
original = pd.read_excel('datos.xlsx')

# %%
original
# Out:
#     INEGI. Sistema de Cuentas Nacionales de México. Indicador Trimestral de la Actividad Económica Estatal. Año Base 2013. Serie del primer trimestre de 2003 al tercer trimestre de 2018  \
# 0    Actividades económicas por entidad federativa/...
# 1                                                  NaN
# 2                                                  NaN
# 3                                             Concepto
# 4                                                  NaN
# 5               Índice de volumen físico base 2013=100
# 6                             Estados Unidos Mexicanos
# 7                                       Aguascalientes
# 8                                      Baja California
# 9                                  Baja California Sur
# 10                                            Campeche
# 11                                Coahuila de Zaragoza
# 12                                              Colima
# 13                                             Chiapas
# 14                                           Chihuahua
# 15                                    Ciudad de México
# 16                                             Durango
# 17                                          Guanajuato
# 18                                            Guerrero
# 19                                             Hidalgo
# 20                                             Jalisco
# 21                                              México
# 22                                 Michoacán de Ocampo
# 23                                             Morelos
# 24                                             Nayarit
# 25                                          Nuevo León
# 26                                              Oaxaca
# 27                                              Puebla
# 28                                           Querétaro
# 29                                        Quintana Roo
# ..                                                 ...
# 119                                         Guanajuato
# 120                                           Guerrero
# 121                                            Hidalgo
# 122                                            Jalisco
# 123                                             México
# 124                                Michoacán de Ocampo
# 125                                            Morelos
# 126                                            Nayarit
# 127                                         Nuevo León
# 128                                             Oaxaca
# 129                                             Puebla
# 130                                          Querétaro
# 131                                       Quintana Roo
# 132                                    San Luis Potosí
# 133                                            Sinaloa
# 134                                             Sonora
# 135                                            Tabasco
# 136                                         Tamaulipas
# 137                                           Tlaxcala
# 138                    Veracruz de Ignacio de la Llave
# 139                                            Yucatán
# 140                                          Zacatecas
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                      NA No aplica.
# 145                                  RCifras revisadas
# 146                               PCifras preliminares
# 147  Nota: Los resultados del Indicador Trimestral ...
# 148  Fuente: INEGI. Sistema de Cuentas Nacionales d...
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 0          NaN        NaN        NaN        NaN        NaN         NaN
# 1          NaN        NaN        NaN        NaN        NaN         NaN
# 2          NaN        NaN        NaN        NaN        NaN         NaN
# 3         2003        NaN        NaN        NaN        NaN        2004
# 4           T1         T2         T3         T4      Anual          T1
# 5          NaN        NaN        NaN        NaN        NaN         NaN
# 6        78.79    81.0366    79.5701    81.7542    80.2877     81.5074
# 7      67.4073    68.7221    72.1976    72.1898    70.1292     69.0168
# 8      87.3742    86.4747     85.542    83.8903    85.8203     88.0776
# 9      64.9166     64.942    65.5271     69.064    66.1124     63.9815
# 10     143.503    143.507    147.533    146.532    145.269     144.278
# 11       79.01    79.7805    81.5464    84.1282    81.1163     81.8687
# 12     69.6376    74.9986    75.6288    76.0865    74.0879     71.5267
# 13     93.1056    88.4684    83.9927    87.7275    88.3236     86.8687
# 14     73.7525    73.1616    75.5507    80.2301    75.6738     75.1885
# 15     77.4974    83.4109    76.8175    81.4477    79.7934     79.9774
# 16     75.7721    77.5425    83.1042    87.1367    80.8889     81.3803
# 17     72.2139    73.8634    73.6329    75.1923    73.7256     73.2597
# 18      78.741    82.7531    83.9554    88.5623     83.503     85.3071
# 19     72.9656    79.1545    77.8715    80.9466    77.7345     79.4696
# 20     77.4821    78.3751    77.3101    79.0157    78.0458     79.9749
# 21     74.6355    79.4433    76.9793    76.1316    76.7974     75.6827
# 22     80.2282     81.607    79.0299    86.8079    81.9183     80.0825
# 23     84.2648    85.1783     86.587    91.1047    86.7837     89.6217
# 24     73.6941    73.3113    71.5473    75.2119    73.4411     84.7963
# 25     70.8872    72.2161    70.9321    71.7916    71.4568     73.6245
# 26     80.0686    83.6179    80.6948     86.292    82.6683     85.5076
# 27     74.6615    78.0364    75.8981     76.384     76.245     78.2473
# 28     64.6202    65.8655    67.0887    67.5675    66.2855     67.3571
# 29     63.9685    65.2281    63.6418    63.2655     64.026     68.7359
# ..         ...        ...        ...        ...        ...         ...
# 119        NaN        NaN        NaN        NaN        NaN   0.0504522
# 120        NaN        NaN        NaN        NaN        NaN    0.116572
# 121        NaN        NaN        NaN        NaN        NaN    0.121894
# 122        NaN        NaN        NaN        NaN        NaN    0.206015
# 123        NaN        NaN        NaN        NaN        NaN    0.115993
# 124        NaN        NaN        NaN        NaN        NaN -0.00424812
# 125        NaN        NaN        NaN        NaN        NaN   0.0791588
# 126        NaN        NaN        NaN        NaN        NaN   0.0933477
# 127        NaN        NaN        NaN        NaN        NaN     0.24986
# 128        NaN        NaN        NaN        NaN        NaN    0.108347
# 129        NaN        NaN        NaN        NaN        NaN    0.151072
# 130        NaN        NaN        NaN        NaN        NaN   0.0710589
# 131        NaN        NaN        NaN        NaN        NaN   0.0871387
# 132        NaN        NaN        NaN        NaN        NaN   0.0702142
# 133        NaN        NaN        NaN        NaN        NaN    0.113814
# 134        NaN        NaN        NaN        NaN        NaN    0.157227
# 135        NaN        NaN        NaN        NaN        NaN    0.102243
# 136        NaN        NaN        NaN        NaN        NaN   0.0856241
# 137        NaN        NaN        NaN        NaN        NaN    0.168042
# 138        NaN        NaN        NaN        NaN        NaN     0.42063
# 139        NaN        NaN        NaN        NaN        NaN   0.0764705
# 140        NaN        NaN        NaN        NaN        NaN   0.0460649
# 141        NaN        NaN        NaN        NaN        NaN         NaN
# 142        NaN        NaN        NaN        NaN        NaN         NaN
# 143        NaN        NaN        NaN        NaN        NaN         NaN
# 144        NaN        NaN        NaN        NaN        NaN         NaN
# 145        NaN        NaN        NaN        NaN        NaN         NaN
# 146        NaN        NaN        NaN        NaN        NaN         NaN
# 147        NaN        NaN        NaN        NaN        NaN         NaN
# 148        NaN        NaN        NaN        NaN        NaN         NaN
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9  ... Unnamed: 71 Unnamed: 72  \
# 0          NaN         NaN         NaN  ...         NaN         NaN
# 1          NaN         NaN         NaN  ...         NaN         NaN
# 2          NaN         NaN         NaN  ...         NaN         NaN
# 3          NaN         NaN         NaN  ...       2017R         NaN
# 4           T2          T3          T4  ...          T1          T2
# 5          NaN         NaN         NaN  ...         NaN         NaN
# 6      84.3903      82.518     85.3056  ...     108.895     110.978
# 7      73.0645     73.1529     77.6805  ...     130.736     127.981
# 8       94.539     90.5478     90.3011  ...     111.774     118.047
# 9      72.3299     70.1919     77.0669  ...     116.676     122.221
# 10      146.81      148.51     148.161  ...     78.4714      75.827
# 11     83.2128     83.6085     85.1175  ...      110.39     115.164
# 12     72.9748     75.2984     76.8189  ...     111.108     112.821
# 13     84.4741     81.9157     86.1568  ...     104.298     99.4699
# 14     79.4758     80.0442     81.6218  ...     111.148     116.981
# 15     86.7821     80.3085     86.1747  ...     110.098     113.938
# 16     81.1468     85.2961     85.7603  ...     103.297     106.162
# 17     77.7061     74.5255     77.8869  ...     119.089     121.399
# 18     87.2138      89.377     90.1091  ...      106.36      108.45
# 19     83.8941     83.1216      85.227  ...     111.055     115.297
# 20     80.5821     79.7616     81.3996  ...     114.472     114.522
# 21     80.3725      78.134     80.4538  ...     107.951     113.035
# 22     83.7439     83.7054     87.4336  ...     115.948     115.132
# 23     84.1562     85.0425     92.0022  ...     112.196      108.05
# 24     85.2637     78.6783     86.6146  ...      116.16     120.587
# 25     76.6134     74.9891     76.9389  ...     111.479     112.874
# 26       87.49      84.308     86.0647  ...     101.401     101.143
# 27      79.842      78.596     75.9986  ...     110.478     113.046
# 28     70.5366     73.0846     73.9275  ...     126.014     123.782
# 29     71.0199     68.0579     70.8559  ...     118.962     121.673
# ..         ...         ...         ...  ...         ...         ...
# 119   0.180242   0.0426374    0.125284  ...    0.342936    0.216483
# 120  0.0769991   0.0953102   0.0264645  ...  -0.0470814  0.00125678
# 121  0.0863634    0.097429   0.0773122  ...  -0.0150206  -0.0253341
# 122   0.177343    0.200615    0.189876  ...    0.302951   0.0952525
# 123   0.100076    0.126646     0.46138  ...    0.401847    0.233702
# 124  0.0605945     0.13503   0.0175849  ...    0.142092  -0.0084591
# 125 -0.0146856  -0.0225999   0.0127812  ...    0.123532   0.0471899
# 126  0.0977094   0.0593704    0.092398  ...   0.0229952 -0.00347479
# 127   0.390253    0.366686    0.452805  ...    0.303403     0.23965
# 128  0.0749959   0.0712697 -0.00436364  ... -0.00245508  -0.0797972
# 129  0.0739652     0.11255  -0.0156511  ...    0.242835    0.169731
# 130   0.117913    0.154144    0.159138  ...    0.186566   0.0667695
# 131   0.102927   0.0799266    0.133706  ...   0.0783725   0.0533641
# 132   0.133419   0.0716602    0.142714  ...    0.135099   0.0583468
# 133   0.132874    0.127675    0.147663  ...  -0.0207936     0.02484
# 134   0.085344    0.162844    0.198124  ...    0.124417   0.0641663
# 135   0.113536    0.174063     0.13096  ...   -0.276723   -0.101315
# 136   0.098139    0.197271    0.208045  ...  0.00745324   0.0119731
# 137  0.0381774 -0.00659749   0.0110489  ...  -0.0265609  0.00219659
# 138   0.217885    0.114825    0.213656  ...   0.0216738  -0.0014037
# 139  0.0727974   0.0373618   0.0485265  ...    0.102659   0.0177181
# 140  0.0668284   0.0116757   0.0111936  ...   0.0140721   0.0100446
# 141        NaN         NaN         NaN  ...         NaN         NaN
# 142        NaN         NaN         NaN  ...         NaN         NaN
# 143        NaN         NaN         NaN  ...         NaN         NaN
# 144        NaN         NaN         NaN  ...         NaN         NaN
# 145        NaN         NaN         NaN  ...         NaN         NaN
# 146        NaN         NaN         NaN  ...         NaN         NaN
# 147        NaN         NaN         NaN  ...         NaN         NaN
# 148        NaN         NaN         NaN  ...         NaN         NaN
#
#     Unnamed: 73 Unnamed: 74  Unnamed: 75  Unnamed: 76 Unnamed: 77  \
# 0           NaN         NaN          NaN          NaN         NaN
# 1           NaN         NaN          NaN          NaN         NaN
# 2           NaN         NaN          NaN          NaN         NaN
# 3           NaN         NaN          NaN         2018         NaN
# 4            T3          T4        Anual          T1R         T2R
# 5           NaN         NaN          NaN          NaN         NaN
# 6       109.554     114.582      111.002      110.152     113.856
# 7       129.607     131.003      129.832      133.044     131.013
# 8       117.439     120.725      116.996      115.181     121.264
# 9       136.595     144.636      130.032      142.216     147.402
# 10      71.2927     73.0586      74.6624      74.2672     73.8323
# 11      113.828     115.965      113.837      112.603     116.868
# 12      115.438     123.413      115.695      113.551     116.639
# 13      97.2229     100.301      100.323      102.001     97.7014
# 14      116.727     122.559      116.854       109.26     118.936
# 15      111.356     120.236      113.907      110.541     117.462
# 16      107.274     107.083      105.954      100.545     105.224
# 17      120.971     124.974      121.608      119.892     125.349
# 18      106.708      111.76      108.319      110.955     110.325
# 19      113.312      119.64      114.826      115.021     118.327
# 20      117.884      121.42      117.074       118.72     120.092
# 21      111.352     121.763      113.525      112.395     117.653
# 22       113.37     124.008      117.114      119.891     120.105
# 23      105.005     118.477      110.932      109.355     108.522
# 24      114.376     119.001      117.531      117.176     117.977
# 25      113.472     115.908      113.433      112.291     117.004
# 26      96.4553     104.219      100.805      103.724     106.547
# 27       112.45     116.398      113.093      111.436     120.142
# 28      124.262       127.4      125.364      125.608      126.47
# 29      123.954     123.857      122.111      123.797     127.838
# ..          ...         ...          ...          ...         ...
# 119    0.142915    0.094999     0.197321    0.0280606    0.135264
# 120 -0.00105241   0.0438452   3.3734e-05    0.0590213   0.0236346
# 121    0.016933   0.0466665   0.00632589    0.0537867   0.0403228
# 122    0.164138     0.15951     0.179277     0.254001    0.326814
# 123     0.29093    0.655514      0.39802     0.356146    0.363121
# 124   0.0562703    0.109768    0.0747048    0.0831974    0.102991
# 125 -0.00235439   0.0611625    0.0569998   -0.0303817  0.00495331
# 126   0.0125973   0.0169575     0.012219   0.00618147   -0.015576
# 127    0.214897     0.12226     0.218485    0.0536303    0.267616
# 128  -0.0937967  -0.0349535   -0.0529188    0.0334856   0.0764241
# 129     0.23865     0.15201     0.199923    0.0292145    0.212256
# 130   0.0695975   0.0376958    0.0889211  -0.00762292   0.0495465
# 131   0.0845282   0.0592214    0.0686671    0.0639382   0.0799908
# 132   0.0751693   0.0861512    0.0883082    0.0889951   0.0851867
# 133   0.0470585    0.013671    0.0164104    0.0659492   0.0567139
# 134  -0.0375722  -0.0367223    0.0273363   -0.0020418  -0.0119311
# 135  -0.0779592   -0.164332     -0.15432   -0.0863407   -0.202257
# 136  -0.0274727  0.00613155 -0.000421789   0.00862469   0.0289267
# 137  -0.0134739  0.00391582  -0.00820461  0.000606333  -0.0151369
# 138  -0.0731023   -0.140793    -0.049766    -0.092768   0.0829134
# 139   0.0492526  0.00243593    0.0421335    0.0313364   0.0609117
# 140  -0.0235652   -0.016202  -0.00412745    0.0150585  0.00991634
# 141         NaN         NaN          NaN          NaN         NaN
# 142         NaN         NaN          NaN          NaN         NaN
# 143         NaN         NaN          NaN          NaN         NaN
# 144         NaN         NaN          NaN          NaN         NaN
# 145         NaN         NaN          NaN          NaN         NaN
# 146         NaN         NaN          NaN          NaN         NaN
# 147         NaN         NaN          NaN          NaN         NaN
# 148         NaN         NaN          NaN          NaN         NaN
#
#      Unnamed: 78 Unnamed: 79 Unnamed: 80
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            T3P          T4       Anual
# 5            NaN         NaN         NaN
# 6        112.288         NaN         NaN
# 7        136.134         NaN         NaN
# 8        119.845         NaN         NaN
# 9        144.265         NaN         NaN
# 10       74.3678         NaN         NaN
# 11       114.331         NaN         NaN
# 12       118.044         NaN         NaN
# 13       98.5936         NaN         NaN
# 14       118.678         NaN         NaN
# 15       115.842         NaN         NaN
# 16       107.917         NaN         NaN
# 17       121.514         NaN         NaN
# 18       108.775         NaN         NaN
# 19       116.703         NaN         NaN
# 20       120.846         NaN         NaN
# 21       114.829         NaN         NaN
# 22       111.472         NaN         NaN
# 23       108.945         NaN         NaN
# 24       115.382         NaN         NaN
# 25       118.288         NaN         NaN
# 26        100.96         NaN         NaN
# 27       115.923         NaN         NaN
# 28       127.928         NaN         NaN
# 29       128.484         NaN         NaN
# ..           ...         ...         ...
# 119    0.0188395         NaN         NaN
# 120    0.0263917         NaN         NaN
# 121    0.0457015         NaN         NaN
# 122     0.176019         NaN         NaN
# 123     0.277014         NaN         NaN
# 124    -0.039799         NaN         NaN
# 125    0.0418764         NaN         NaN
# 126   0.00608591         NaN         NaN
# 127     0.316157         NaN         NaN
# 128    0.0645382         NaN         NaN
# 129     0.105221         NaN         NaN
# 130    0.0684511         NaN         NaN
# 131    0.0595568         NaN         NaN
# 132    0.0769378         NaN         NaN
# 133 -0.000686377         NaN         NaN
# 134   -0.0120672         NaN         NaN
# 135    -0.186988         NaN         NaN
# 136    0.0460849         NaN         NaN
# 137   -0.0148153         NaN         NaN
# 138     0.225039         NaN         NaN
# 139     0.063006         NaN         NaN
# 140   0.00773938         NaN         NaN
# 141          NaN         NaN         NaN
# 142          NaN         NaN         NaN
# 143          NaN         NaN         NaN
# 144          NaN         NaN         NaN
# 145          NaN         NaN         NaN
# 146          NaN         NaN         NaN
# 147          NaN         NaN         NaN
# 148          NaN         NaN         NaN
#
# [149 rows x 81 columns]

# %%
datos = original[6:141]

# %%
datos.columns=datos.columns.droplevel(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-60408d4d0edb> in <module>
# ----> 1 datos.columns=datos.columns.droplevel(0)
#
# ~/pythonista/lib/python3.6/site-packages/pandas/core/indexes/base.py in droplevel(self, level)
#    1518             raise ValueError("Cannot remove {} levels from an index with {} "
#    1519                              "levels: at least one level must be "
# -> 1520                              "left.".format(len(level), self.nlevels))
#    1521         # The two checks above guarantee that here self is a MultiIndex
#    1522
#
# ValueError: Cannot remove 1 levels from an index with 1 levels: at least one level must be left.

# %%
columnas = datos.iloc[4]

# %%
columnas.values
# Out:
# array([nan, 'T1', 'T2', 'T3', 'T4', 'Anual', 'T1', 'T2', 'T3', 'T4',
#        'Anual', 'T1', 'T2', 'T3', 'T4', 'Anual', 'T1', 'T2', 'T3', 'T4',
#        'Anual', 'T1', 'T2', 'T3', 'T4', 'Anual', 'T1', 'T2', 'T3', 'T4',
#        'Anual', 'T1', 'T2', 'T3', 'T4', 'Anual', 'T1', 'T2', 'T3', 'T4',
#        'Anual', 'T1', 'T2', 'T3', 'T4', 'Anual', 'T1', 'T2', 'T3', 'T4',
#        'Anual', 'T1', 'T2', 'T3', 'T4', 'Anual', 'T1', 'T2', 'T3', 'T4',
#        'Anual', 'T1', 'T2', 'T3', 'T4', 'Anual', 'T1', 'T2', 'T3', 'T4',
#        'Anual', 'T1', 'T2', 'T3', 'T4', 'Anual', 'T1R', 'T2R', 'T3P',
#        'T4', 'Anual'], dtype=object)

# %%
columnas = ('Concepto','2003_T1', '2003_T2', '2003_T3', '2003_T4', '2003',
                         '2004_T1', '2004_T2', '2004_T3', '2004_T4', '2004',
                         '2005_T1', '2005_T2', '2005_T3', '2005_T4', '2005',
                         '2006_T1', '2006_T2', '2006_T3', '2006_T4', '2006',
                         '2007_T1', '2007_T2', '2007_T3', '2007_T4', '2007',
                         '2008_T1', '2008_T2', '2008_T3', '2008_T4', '2008',
                         '2009_T1', '2009_T2', '2009_T3', '2009_T4', '2009'
                         '2010_T1', '2010_T2', '2010_T3', '2010_T4', '2010',
                         '2011_T1', '2011_T2', '2011_T3', '2011_T4', '2011',
                         '2012_T1', '2012_T2', '2012_T3', '2012_T4', '2012',
                         '2013_T1', '2013_T2', '2013_T3', '2013_T4', '2013',
                         '2014_T1', '2014_T2', '2014_T3', '2014_T4', '2014',
                         '2015_T1', '2015_T2', '2015_T3', '2015_T4', '2015',
                         '2016_T1', '2016_T2', '2016_T3', '2016_T4', '2016',
                         '2017_T1', '2017_T2', '2017_T3', '2017_T4', '2017',
                         '2018_T1', '2018_T2', '2018_T3', '2018_T4', '2018', 'incognito_1')

# %%
datos.columns=columnas

# %%
datos_filtrados = datos[6:73].set_index('Concepto')

# %%
datos_filtrados

# %%
datos_filtrados.to_csv('datos_filtrados.csv')

# %%
nuevos_datos = pd.read_csv('datos_filtrados.csv')

# %%
nuevos_datos

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2019.</p>

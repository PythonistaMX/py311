# %% [markdown]
# [![img/pythonista.png](img/pythonista.png)](https://www.pythonista.io)

# %% [markdown]
# # Gestión de fechas.
#
# El proyecto *Pandas* fue creado originalmente para poder manejar datos financieros, y por lo tanto, el manejo de fechas y series de tiempo es una parte fundamental de su funcionalidad. En esta sección, exploraremos cómo trabajar con fechas en *Pandas*.

# %% [markdown]
# En *Pandas*, las series de tipo `datetime` cuentan con un *accessor* especial llamado `.dt`, el cual permite extraer componentes y realizar transformaciones sobre los valores de fechas en una serie.

# %%
from datetime import datetime
import pandas as pd
import numpy as np

# %% [markdown]
# ## La función `pd.date_range()`.
#
# La función `pd.date_range()` permite generar un rango de fechas con una frecuencia específica.
#
#
# ```
# pd.date_range(start=<inicio>, end=<fin>, freq=<frecuencia>)
# ```
# Donde:
# * `<inicio>` es la fecha de inicio del rango.
# * `<fin>` es la fecha de fin del rango.
# * `<frecuencia>` es la frecuencia con la que se generan las fechas.
#
# Las frecuencias más comunes son:
# * `D`: diaria.
# * `ME`: mensual (fin de mes).
# * `YE`: anual (fin de año).
# * `h`: horaria.
# * `min`: por minuto.
# * `s`: por segundo.
#
# El resultado de `pd.date_range()` es un objeto de tipo `DatetimeIndex`, que es una colección de fechas.
#
# La documentación de `pd.date_range()` se puede encontrar en:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.date_range.html

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda regresará un objeto `DatetimeIndex` con fechas diarias desde el 1 de enero de 2019 hasta el 31 de diciembre de 2019.

# %%
pd.date_range('2019-01-01', '2019-12-31', freq='D')

# %% [markdown]
# * La siguiente celda regresará un objeto `DatetimeIndex` con fechas semanales desde el 1 de enero de 2019 hasta el 31 de diciembre de 2019 usando la zona horaria `"America/Mexico_City"`.

# %%
pd.date_range('2019-01-01', '2019-12-31', freq='W', tz='America/Mexico_City')

# %% [markdown]
# * La siguiente celda regresará un objeto `DatetimeIndex` con un rango horario que va desde las `00:00:00` del 1 de enero de 2019 hasta las `23:00:00` del 7 de enero de 2019.

# %%
pd.date_range('2019-01-01', '2019-01-07', freq='h')

# %% [markdown]
# ## *Dataframe* ilustrativo.

# %% [markdown]
# Se creará un *dataframe* sintético llamado `ventas` con un índice de fechas que van del 1 de enero de 2019 al 31 de diciembre de 2019 en frecuencia diaria y una columna con valores numéricos asociados.

# %%
fechas = pd.date_range(start="2019-01-01", end="2019-12-31", freq="D")
fechas

# %%
ventas = pd.DataFrame({'fechas': fechas, 'ventas': np.random.randint(1000, 5000, size=len(fechas))}).set_index('fechas')

# %%
ventas

# %% [markdown]
# ## El accesor `Series.dt`.
#
# Las series de tipo `datetime` cuentan con el accesor `.dt`, el cual permite extraer componentes específicos de las fechas, como el año, mes, día, etc.
#
# Los componentes más comunes que se pueden extraer con `.dt` son:
# * `.dt.year`: extrae el año de la fecha.
# * `.dt.month`: extrae el mes de la fecha.
# * `.dt.day`: extrae el día de la fecha.
# * `.dt.hour`: extrae la hora de la fecha.
# * `.dt.minute`: extrae los minutos de la fecha.
# * `.dt.second`: extrae los segundos de la fecha.
# * `.dt.weekday`: extrae el día de la semana de la fecha (0 para lunes, 6 para domingo).
# * `.dt.day_name()`: extrae el nombre del día de la semana de la fecha.
# * `.dt.month_name()`: extrae el nombre del mes de la fecha.
#
# La documentación de las propiedades del accesor `Series.dt` se puede encontrar en:
#
# https://pandas.pydata.org/docs/reference/series.html#api-series-dt
#
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda creará una serie de fechas a partir del índice de `ventas` y extraerá el año de cada fecha con `.dt.year`.

# %%
serie_fechas = ventas.index.to_series()
serie_fechas.dt.year.head()

# %% [markdown]
# * La siguiente celda extraerá el nombre del día de la semana de cada fecha con `.dt.day_name()`.

# %%
serie_fechas.dt.day_name().head()

# %% [markdown]
# * La siguiente celda creará un *dataframe* con varios componentes de fecha extraídos del índice de `ventas`.

# %%
pd.DataFrame({
    'año': serie_fechas.dt.year,
    'mes': serie_fechas.dt.month,
    'dia': serie_fechas.dt.day,
    'nombre_mes': serie_fechas.dt.month_name()
}).head()

# %% [markdown]
# * La siguiente celda extraerá el día de la semana de cada fecha con `.dt.weekday` (0 para lunes, 6 para domingo).

# %%
serie_fechas.dt.weekday.head()

# %% [markdown]
# * Para demostrar las propiedades `.dt.hour`, `.dt.minute` y `.dt.second`, la siguiente celda creará una serie con marcas de tiempo horarias a partir de las `08:30:15` del 1 de enero de 2019.

# %%
serie_tiempo = pd.Series(pd.date_range('2019-01-01 08:30:15', periods=5, freq='90min'))
serie_tiempo

# %% [markdown]
# * La siguiente celda creará un *dataframe* con las propiedades de tiempo `.dt.hour`, `.dt.minute` y `.dt.second` extraídos de `serie_tiempo`.

# %%
pd.DataFrame({
    'hora': serie_tiempo.dt.hour,
    'minuto': serie_tiempo.dt.minute,
    'segundo': serie_tiempo.dt.second
})

# %% [markdown]
# ## Índices con datos temporales.
#
# *Pandas* permite utilizar fechas como índices en nuestros *dataframes*, lo que facilita el manejo de datos temporales. Cuando el índice es de tipo `DatetimeIndex`, es posible seleccionar rangos de fechas directamente con cadenas de caracteres en notación `'YYYY-MM'` o `'YYYY-MM-DD'`.

# %% [markdown]
# **Ejemplo:**

# %% [markdown]
# * La siguiente celda regresará los datos del *dataframe* `ventas` desde el 1 de enero de 2019 hasta el 31 de marzo de 2019.

# %%
# Registros del primer trimestre
ventas['2019-01':'2019-03']

# %% [markdown]
# ## El método `df.resample()`.
#
# El método `resample()` permite reagrupar una serie temporal por una frecuencia de tiempo y aplicar una función de agregación.
#
# ```
# df.resample(<frecuencia>).<func>()
# ```
# Donde:
# * `<frecuencia>` es la frecuencia con la que se desea reagrupar los datos.
# * `<func>` es la función de agregación que se desea aplicar, como `sum()`, `mean()`, `max()`, etc.
#
# Frecuencias comunes:
#
# | Alias | Frecuencia |
# | :--- | :--- |
# | `'D'` | Diaria |
# | `'W'` | Semanal |
# | `'ME'` | Fin de mes |
# | `'QE'` | Fin de trimestre |
# | `'YE'` | Fin de año |
#
# El resultado de `df.resample()` es un nuevo *dataframe* con el índice reagrupado según la frecuencia especificada y los valores agregados según la función aplicada de forma similar a `groupby()`.

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda calculará la suma de ventas semanales del *dataframe* `ventas` utilizando el método `resample()`.

# %%
ventas.resample('W').sum()

# %% [markdown]
# * La siguiente celda calculará el promedio de ventas mensuales del *dataframe* `ventas` utilizando el método `resample()`.

# %%
ventas.resample('ME').mean()

# %% [markdown]
# * La siguiente celda calculará una serie de estadísticas típicas (suma, promedio, máximo y mínimo) de ventas trimestrales del *dataframe* `ventas` utilizando el método `resample()`.

# %%
# Múltiples agregaciones por trimestre
ventas.resample('QE').agg(['sum', 'mean', 'max', 'min'])

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2017-2026.</p>
